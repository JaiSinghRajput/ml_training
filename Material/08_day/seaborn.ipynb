# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# from matplotlib.patches import Ellipse, Polygon

# %%
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv
df = sns.load_dataset("tips")
df.to_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(x=df["total_bill"],y=df["tip"],data=df,marker="o",color="black")
plt.title("Graph")
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
sns.histplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(x=df["day"],y=df["total_bill"])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## sns Plots
# - categorical plots
# - relational plots

# %%
sns.relplot(x=df["total_bill"],y=df["tip"])

# %%
sns.catplot(x=df["day"],y=df["tip"],kind="box",hue=df["smoker"])

# %%
sns.boxplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
df = pd.read_csv("tips.csv")
q1=df["total_bill"].quantile(0.25)
q3=df["total_bill"].quantile(0.75)
iqr = q3-q1
print(f"q1 = {q1},q3={q3},iqr={iqr}")
lower_bound = q1-(1.5*iqr)
upper_bound = q3-(1.5*iqr)
df["total_bill"] = df["total_bill"]>upper_bound
df["total_bill"] = df["total_bill"]<lower_bound
sns.boxplot(df["total_bill"])
# Out:
# q1 = 13.3475,q3=24.127499999999998,iqr=10.779999999999998
# <Axes: ylabel='total_bill'>

# %%
sns.displot(df['total_bill'],kde=True)

# %%
sns.jointplot(x=df["total_bill"],y=df["tip"],kind="hex")

# %%
sns.pairplot(df)

# %%
sns.relplot(x=df["total_bill"],y=df["tip"],hue=df["time"],style=df["size"],col=df["day"])

# %%
"day"
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
